# %% [markdown]
# # Image to Text avec Pytesseract

# %%
import os
from PIL import Image
from pytesseract import image_to_string

# %%
img = Image.open('/home/katia/Documents/Bollore_Bot/POC-NLP/image/extraire.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=134x35 at 0x7F299C03DB50>

# %%
#text = image_to_string(Image.open(os.path.join('/home/katia/Documents/Bollore_Bot/POC-NLP/image', 'extraire.png')))
#print text

# %%
from PIL import Image, ImageEnhance, ImageFilter
import pytesseract
import os
img = Image.open(os.path.join('/home/katia/Documents/Bollore_Bot/POC-NLP/image', 'qualite.png'))
img = img.convert('RGBA')

# %%
pix = img.load()
for y in range(img.size[1]):
    for x in range(img.size[0]):
        if pix[x, y][0] < 102 or pix[x, y][1] < 102 or pix[x, y][2] < 102:
            pix[x, y] = (0, 0, 0, 255)
        else:
            pix[x, y] = (255, 255, 255, 255)
img.save('regenerer_nb.jpg')
text = pytesseract.image_to_string(Image.open('regenerer_nb.jpg'))
os.remove('regenerer_nb.jpg')
print(text)
# Out:
# Quanmte’

# %% [markdown]
# # Image to Text Opencv PIL

# %%
import cv2
import numpy as np
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import scipy.ndimage
import scipy

# Path of working folder on Disk
src_path = "/home/katia/Documents/Bollore_Bot/POC-NLP/image/"

# Read image with opencv
img = cv2.imread(src_path + "reinitialiser.png")

# Convert to gray
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

#appliqué filtre gaussien
img_modified = scipy.ndimage.filters.gaussian_filter(img, sigma=3.0)

print img_modified.max(), img_modified.min()
print img_modified.shape

#plt.imshow(img_modified[:,:], cmap = plt.get_cmap('gray'),vmin=img_modified.min(),vmax=img_modified.max())
#plt.colorbar()
#plt.savefig(src_path +"GaussianFilter1.png")


# Recognize text with tesseract for python
result = pytesseract.image_to_string(Image.open(src_path + "GaussianFilter1.png"))
#print(result)
# Out:
# 253 142
# (42, 110)

# %%
import cv2
import numpy as np
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import scipy.ndimage
import scipy

# Path of working folder on Disk
src_path = "/home/katia/Documents/Bollore_Bot/POC-NLP/image/"

# Read image with opencv
imge = cv2.imread(src_path + "reinitialiser.png")

# Convert to gray
img = cv2.cvtColor(imge, cv2.COLOR_RGB2GRAY)
#hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)


lower_red = np.array([30,150,50])
upper_red = np.array([255,255,180])
    
mask = cv2.inRange(img, lower_red, upper_red)
res = cv2.bitwise_and(imge,imge, mask= mask)

blur = cv2.GaussianBlur(res,(15,15),0)
#cv2.imshow('Gaussian Blurring',blur)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-2e140f327991> in <module>()
#      22 upper_red = np.array([255,255,180])
#      23
# ---> 24 mask = cv2.inRange(img, lower_red, upper_red)
#      25 res = cv2.bitwise_and(imge,imge, mask= mask)
#      26
#
# error: /io/opencv/modules/core/src/arithm.cpp:1944: error: (-209) The lower bounary is neither an array of the same size and same type as src, nor a scalar in function inRange

# %%
#!/usr/bin/env python2
# -*- coding: utf-8 -*-
"""
Created on Mon Jun 26 15:09:02 2017

@author: katia
"""
import cv2
import numpy as np
import pytesseract
from PIL import Image

# Path of working folder on Disk
src_path = "/home/katia/Documents/Bollore_Bot/POC-NLP/image/"

def get_string(img_path):
    # Read image with opencv
    img = cv2.imread(img_path)
    
    # Convert to gray
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # Apply dilation and erosion to remove some noise
    kernel = np.ones((1, 1), np.uint8)
    img = cv2.dilate(img, kernel, iterations=1)
    img = cv2.erode(img, kernel, iterations=1)

    # Write image after removed noise
    cv2.imwrite(src_path + "removed_noise.png", img)

    #  Apply threshold to get image with only black and white
    #img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)

    # Write the image after apply opencv to do some ...
    cv2.imwrite(src_path + "thres.png", img)

    # Recognize text with tesseract for python
    result = pytesseract.image_to_string(Image.open(src_path + "thres.png"))

    # Remove template file
    #os.remove(temp)

    return result


print '--- Start recognize text from image ---'
print get_string(src_path + "recherche.png")

print "------ Done -------"
# Out:
# --- Start recognize text from image ---
# Recherche événement
#
#
#
# Termma‘ W
# Recherche Texte
#
# Femme d‘evehemeht
# Type d‘e’vénement
# Du ﬁ 7 7
#
# Au ﬁ 7 7
#
# Recherche mmpxe
#
#
#
# oehe \e parc
#
#
#
#
#
# ﬂ Evehemeht/ Page
#
#
#
#
#
# Recherche avancée
# Item Parc N“
#
# Date Entree ﬁ 7 7
#
# EL 0
#
#
#
# Type d‘ltem Parc
# Cece Item Parc
# Zche
#
# Rangee
#
# Travee
#
# Destmatmn smvante
# Made de transport
#
# Item Parc Status
#
# UH
#
# Sé‘EcHoN‘Er ﬂ
# VemHez se‘ectmnnerdaburd u
#
# s‘u vuus pm Sé‘EcHDWvEr we ﬂ
# 0
#
# 1
#
# Sé‘EcHoN‘Er
#
# U.
# ------ Done -------

# %%
img.show()

# %% [markdown]
# # Correction d'orthographe HMM

# %%
def HMM:

# %% [markdown]
# # lecture de fichier texte

# %%
import nltk
from numpy import array, ones, zeros, multiply
import numpy as np
import sys
import pprint, pickle

UNK = "<unk>"  # token to map all out-of-vocabulary words (OOVs)
UNKid = 0      # index for UNK

# %%
train10 =   pickle.load(open('/home/katia/Documents/Bollore_Bot/POC-NLP/HMM/typos-data /train10.pkl', 'rb'))

# %% [markdown]
# # liste de mots français

# %%
fp = open("/home/katia/Documents/Bollore_Bot/POC-NLP/Manuel d'utilisation/liste.de.mots.francais.frgut.txt")
content = fp.read();
lines = content.split("\n")

# %%
len(lines)
# Out:
# 336532

# %%
lines
# Out:
# ['a',
#  '\xc3\xa0',
#  'abaissa',
#  'abaissable',
#  'abaissables',
#  'abaissai',
#  'abaissaient',
#  'abaissais',
#  'abaissait',
#  'abaiss\xc3\xa2mes',
#  'abaissant',
#  'abaissante',
#  'abaissantes',
#  'abaissants',
#  'abaissas',
#  'abaissasse',
#  'abaissassent',
#  'abaissasses',
#  'abaissassiez',
#  'abaissassions',
#  'abaiss\xc3\xa2t',
#  'abaiss\xc3\xa2tes',
#  'abaisse',
#  'abaiss\xc3\xa9',
#  'abaiss\xc3\xa9e',
#  'abaiss\xc3\xa9es',
#  'abaisse-langue',
#  'abaissement',
#  'abaissements',
#  'abaissent',
#  'abaisser',
#  'abaissera',
#  'abaisserai',
#  'abaisseraient',
#  'abaisserais',
#  'abaisserait',
#  'abaisseras',
#  'abaiss\xc3\xa8rent',
#  'abaisserez',
#  'abaisseriez',
#  'abaisserions',
#  'abaisserons',
#  'abaisseront',
#  'abaisses',
#  'abaiss\xc3\xa9s',
#  'abaisseur',
#  'abaisseurs',
#  'abaissez',
#  'abaissiez',
#  'abaissions',
#  'abaissons',
#  'abajoue',
#  'abajoues',
#  'abandon',
#  'abandonna',
#  'abandonnai',
# ...

# %% [markdown]
# # création corpus manuel d'utilisation

# %%
#import re
#création d'un corpus manuel d'utilisation 

#ManuelUtilisateurIPAKI_V01_RevueMN
#cp = open("/home/katia/Documents/Bollore_Bot/POC-NLP/Manuel d'utilisation/liste.de.mots.francais.frgut.txt")
#for line in 
#corpus = cp.read();
#import numpy as np
#data = np.loadtxt('input.txt')
#list_of_elements = np.reshape(data,size(data)).tolist()

# %%
import docx

path = "/home/katia/Documents/Bollore_Bot/POC-NLP/Manuel d'utilisation/ManuelUtilisateurIPAKI_V01_RevueMN.docx"
#document = Document(path + "ManuelUtilisateurIPAKI_V01_RevueMN.docx")

def getText(filename):
    doc = docx.Document(filename)
    fullText=[]
    for p in doc.paragraphs:
        fullText.append(p.text)
    return ('\n'.join(fullText))
#getText(path)

#print(document.paragraphs)

# %% [markdown]
# # Pré-traitement

# %%
#!/usr/bin/python
# -*- encoding: utf8 -*-
from __future__ import unicode_literals

from stop_words import get_stop_words
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import LineTokenizer
import pattern.fr
import unidecode
#import unicodedata
import pandas as pd
#utilisation .txt
data= open("/home/katia/Documents/Bollore_Bot/POC-NLP/Manuel d'utilisation/ManuelUtilisateurIPAKI_V01_RevueMN.txt","r") 
stoplist = get_stop_words('fr')
stoplist.extend(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}','#','-','...','..',':)',';'])
#print(stoplist)
#tokenization de document
#sentence = LineTokenizer(blanklines='discard').tokenize(lower(cp.read()))
texte = data.read()
sentence = texte.lower()

contexte=sentence.split()

#contexte[2].decode('iso-8859-')
len(contexte)
# Out:
# 12871

# %%
def stripNonAlphaNum(text):
    import re
    return re.compile(r'\W+', re.UNICODE).split(text)

sentence = stripNonAlphaNum(texte)
for word in sentence:
    word.lower()

# %%
from nltk.tokenize import SpaceTokenizer
import sys  
import io
import re

word_list = []
with io.open("/home/katia/Documents/Bollore_Bot/POC-NLP/Manuel d'utilisation/ManuelUtilisateurIPAKI_V01_RevueMN.txt", "r", encoding="utf-8") as my_file:
     data = my_file.read() 
SpaceTokenizer().tokenize(data)

w = re.split("(\w+)", data.lower())

# %%
from unidecode import unidecode

print unidecode(u'nomm\xe9e')
# Out:
# nommee

# %%
cp.read()
cp.close()
# Out:
# '\xef\xbb\xbf\nMANUEL D\xe2\x80\x99UTILISATION\n\nGuide Utilisateur\n \n\n\nContenu\n1.\tG\xc3\xa9n\xc3\xa9ralit\xc3\xa9s\t3\n1.1\tIntroduction\t3\n1.1.1.\tObjectifs du document\t3\n1.1.2.\tPr\xc3\xa9sentation d\xe2\x80\x99IPAKI\t4\n1.2\tGlossaire\t7\n1.\tGuide  Utilisateur\t18\n1.1\tLa Recherche\t18\n1.2\tLa Cr\xc3\xa9ation des escales\t28\n1.3\tLa cr\xc3\xa9ation des BLs\t38\n1.4\tLe Booking\t58\n1.5\tSaisir un mouvement d\xe2\x80\x99entr\xc3\xa9e\t63\n1.6\tLa Facturation\t71\n1.6.1.\tFacturation Standard\t79\n1.6.2.\tFacturation Administrative\t82\n1.6.3.\tFacturation Bord\t85\n1.6.4.\tMassive Invoicing\t88\n1.7\tLes Avoirs\t88\n1.8\tLes Rebates\t91\n1.9\tPaiement\t95\n1.10\tLa Livraison\t101\n2.\tFAQ\t111\n\n\n1. G\xc3\xa9n\xc3\xa9ralit\xc3\xa9s\n1.1 Introduction \n1.1.1. Objectifs du document\n\nCe document servira de guide de param\xc3\xa9trages pour les utilisateurs ayant cette attribution.\n\nConventions typographiques et iconographiques\nPour optimiser la taille de ce docume
# ...

# %%
import nltk
sentence = "Mr. Green killed Colonel Mustard in the study with the " + \
           "candlestick. Mr. Green is not a very nice fellow."

print(nltk.ngrams(sentence.split(),2))
# Out:
# <generator object ngrams at 0x7f7099efa280>

# %%
txt = nltk.Text(sentence.split())

print(txt)
# Out:
# <Text: Mr. Green killed Colonel Mustard in the study...>

# %%
txt.collocations()
# Out:
# Mr. Green
